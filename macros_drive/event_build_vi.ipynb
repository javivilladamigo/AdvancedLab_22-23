# %%
# import
import numpy as np
import pandas as pd
from itertools import product

# %%
'''

In channel 0 we have FORM output from the preamplifier, so we can retain its energy (already store in a TH1)
But actually for the RUN1 we have no save data...
In channel 2 we have AMP output so we can obtain the PSA

'''
# Out:
# '\n\nIn channel 0 we have FORM output from the preamplifier, so we can retain its energy (already store in a TH1)\nBut actually for the RUN1 we have no save data...\nIn channel 2 we have AMP output so we can obtain the PSA\n\n'

# %%
# variables to change
#filename_ch0 = '/Users/nicola/Desktop/Advanced Laboratory A/data/20220510/Co60_252Cf_CLYC_MI/UNFILTERED/CH_0@DT5725_1701_Data_Co60_252Cf_CLYC_MI.csv'
#filename_ch2 = '/Users/nicola/Desktop/Advanced Laboratory A/data/20220510/Co60_252Cf_CLYC_MI/UNFILTERED/CH_2@DT5725_1701_Data_Co60_252Cf_CLYC_MI.csv'

#filename_ch0 = '/mnt/c/Users/UTENTE/Downloads/Co60_252Cf_CLYC_MI/UNFILTERED/CH_0@DT5725_1701_Data_Co60_252Cf_CLYC_MI.csv'
#filename_ch2 = '/mnt/c/Users/UTENTE/Downloads/Co60_252Cf_CLYC_MI/UNFILTERED/CH_2@DT5725_1701_Data_Co60_252Cf_CLYC_MI.csv'

filename_ch0 = '/Users/javi/Documents/Padova/2/AdvancedLab/AdvancedLab_22-23/data/20220510/UNFILTERED/60Co_252CF_CLYC_MI/CH_0@DT5725_1701_Data_Co60_252Cf_CLYC_MI.csv'
filename_ch2 = '/Users/javi/Documents/Padova/2/AdvancedLab/AdvancedLab_22-23/data/20220510/UNFILTERED/60Co_252CF_CLYC_MI/CH_2@DT5725_1701_Data_Co60_252Cf_CLYC_MI.csv'


# retain data
df0 = pd.read_csv(filename_ch0, skiprows=1, header=None, sep=';')
df0.columns = (['TIMETAG', 'ENERGY', 'FLAGS'] + [x for x in range(len(df0.columns)-3)])
df2 = pd.read_csv(filename_ch2, skiprows=[0, 197474], header=None, sep=';')
df2.columns = (['TIMETAG', 'ENERGY', 'FLAGS'] + [x for x in range(len(df2.columns)-3)])

# %%
# sort dataframe and print 
df0 = df0.sort_values('TIMETAG')

df0
# Out:
#                 TIMETAG  ENERGY FLAGS     0     1     2     3     4     5  \
# 0             442712000     412   0x0  3258  3258  3254  3254  3257  3257
# 1            2883340000     231   0x0  3252  3252  3258  3258  3253  3253
# 2            4103176000     266   0x0  3260  3260  3253  3253  3252  3252
# 3           11341700000     329   0x0  3260  3260  3262  3262  3260  3260
# 4           11869372000     393   0x0  3250  3250  3266  3266  3257  3257
# ...                 ...     ...   ...   ...   ...   ...   ...   ...   ...
# 139202  244024517252000     356   0x0  3255  3255  3261  3261  3269  3269
# 139203  244025730776000     687   0x0  3253  3253  3255  3255  3261  3261
# 139204  244026296556000     304   0x0  3259  3259  3250  3250  3260  3260
# 139205  244027063424000     407   0x0  3257  3257  3253  3253  3252  3252
# 139206  244031158336000     269   0x0  3249  3249  3247  3247  3245  3245
#
#            6  ...     486     487     488     489     490     491     492  \
# ...

# %%
# sort dataframe and print 
df2 = df2.sort_values('TIMETAG')

df2
# Out:
#                 TIMETAG  ENERGY FLAGS     0     1     2     3     4     5  \
# 0             442700000     134   0x0  3370  3370  3387  3387  3372  3372
# 1             681856000      47   0x0  3377  3377  3384  3384  3396  3396
# 2            1427660000      67   0x0  3379  3379  3376  3376  3383  3383
# 3            2883328000      77   0x0  3375  3375  3384  3384  3380  3380
# 4            4103160000      87   0x0  3379  3379  3379  3379  3382  3382
# ...                 ...     ...   ...   ...   ...   ...   ...   ...   ...
# 197490  253643699848000      60   0x0  3368  3368  3378  3378  3380  3380
# 197491  253644306240000      61   0x0  3381  3381  3379  3379  3385  3385
# 197492  253644484464000      49   0x0  3375  3375  3378  3378  3374  3374
# 197493  253645629120000      88   0x0  3375  3375  3387  3387  3382  3382
# 197494  253646237768000      96   0x0  3385  3385  3370  3370  3380  3380
#
#            6  ...   486   487   488   489   490   491   492   493   494   495
# ...

# %%
# retrieve timestamps (numpy arrays)
timetag0 = np.array(df0.loc[:, 'TIMETAG'])
timetag2 = np.array(df2.loc[:, 'TIMETAG'])

#timetag0 = timetag0[0:1000]
#timetag2 = timetag2[0:1200]

timetag2_temp = timetag2.copy() # modifying the temporary timetag2 array in the for loop 

couples, eliminate_row, diff = [], [], []
counter = 0


for n, i in enumerate(timetag0):
    
    tol = 10**5 #tolerance (ps)
    coinc = np.argwhere(abs(timetag2_temp-i) <= tol) # find the index of timetag2 where the diff is smaller than tol
    
    if np.size(coinc) == 0: 
        eliminate_row.append(n)
        counter+=1 # times when this happens, necessary to correct the position to append in other cases
    
    elif np.size(coinc) == 1: # just one couple found
        
        couples.append([n, coinc[0][0] + (n-counter) ]) # append the timetag0 and timetag2 positions for the coincidence found
        timetag2_temp = np.delete(timetag2_temp, coinc[0][0]) # remove the values that have been associated
    
    else:
        
        for [position] in coinc: 
            diff.append(abs(timetag2_temp[position]-i)) # difference between the candidate timetag2 values and i
        min_index = diff.index(min(diff)) # find the minimum difference index in the diff list
        couples.append([n, coinc[min_index][0] + (n-counter)]) # append the best couple
        diff = [] 
        timetag2_temp = np.delete(timetag2_temp, coinc[min_index][0])

# %%
# Rearrange the DataFrame timetag2 row order to match the timetag0 one and remove the non associated rows of both DataFrames

index_timetag2 = []
for [i,j] in couples:
    index_timetag2.append(j)
    
index_timetag0 = [x for x in range(len(df0.index)) if x not in eliminate_row]

# %%
df0 = df0.loc[index_timetag0]

df0
# Out:
#                 TIMETAG  ENERGY FLAGS     0     1     2     3     4     5  \
# 0             442712000     412   0x0  3258  3258  3254  3254  3257  3257
# 1            2883340000     231   0x0  3252  3252  3258  3258  3253  3253
# 2            4103176000     266   0x0  3260  3260  3253  3253  3252  3252
# 3           11341700000     329   0x0  3260  3260  3262  3262  3260  3260
# 4           11869372000     393   0x0  3250  3250  3266  3266  3257  3257
# ...                 ...     ...   ...   ...   ...   ...   ...   ...   ...
# 139202  244024517252000     356   0x0  3255  3255  3261  3261  3269  3269
# 139203  244025730776000     687   0x0  3253  3253  3255  3255  3261  3261
# 139204  244026296556000     304   0x0  3259  3259  3250  3250  3260  3260
# 139205  244027063424000     407   0x0  3257  3257  3253  3253  3252  3252
# 139206  244031158336000     269   0x0  3249  3249  3247  3247  3245  3245
#
#            6  ...     486     487     488     489     490     491     492  \
# ...

# %%
df2 = df2.loc[index_timetag2]

df2
# Out:
#                 TIMETAG  ENERGY FLAGS     0     1     2     3     4     5  \
# 0             442700000     134   0x0  3370  3370  3387  3387  3372  3372
# 3            2883328000      77   0x0  3375  3375  3384  3384  3380  3380
# 4            4103160000      87   0x0  3379  3379  3379  3379  3382  3382
# 7           11341688000     110   0x0  3382  3382  3385  3385  3381  3381
# 9           11869356000     130   0x0  3395  3395  3363  3363  3374  3374
# ...                 ...     ...   ...   ...   ...   ...   ...   ...   ...
# 197397  244024517240000     115   0x0  3377  3377  3387  3387  3380  3380
# 197399  244025730760000     227   0x0  3378  3378  3372  3372  3380  3380
# 197400  244026296544000     100   0x0  3381  3381  3382  3382  3364  3364
# 197401  244027063408000     136   0x0  3367  3367  3381  3381  3382  3382
# 197406  244031158324000      88   0x0  3370  3370  3372  3372  3361  3361
#
#            6  ...   486   487   488   489   490   491   492   493   494   495
# ...
